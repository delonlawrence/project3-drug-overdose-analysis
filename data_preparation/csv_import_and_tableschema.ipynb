# %%
import pandas as pd
import psycopg2
from sqlalchemy import create_engine

# %%
# Declare database credential variables
DB_NAME = "CT_Overdose_Data"
DB_USER = "postgres"
DB_PASSWORD = "postgres"
DB_HOST = "localhost"

# %%
# Establish the connection
connection = psycopg2.connect(
    database=DB_NAME, user=DB_USER, password=DB_PASSWORD, host=DB_HOST
)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# Cell In[3], line 2
#       1 # Establish the connection
# ----> 2 connection = psycopg2.connect(
#       3     database=DB_NAME, user=DB_USER, password=DB_PASSWORD, host=DB_HOST
#       4 )
#
# File C:\ProgramData\anaconda3\envs\dev2\lib\site-packages\psycopg2\__init__.py:122, in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     119     kwasync['async_'] = kwargs.pop('async_')
#     121 dsn = _ext.make_dsn(dsn, **kwargs)
# --> 122 conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     123 if cursor_factory is not None:
#     124     conn.cursor_factory = cursor_factory
#
# OperationalError: connection to server at "localhost" (::1), port 5432 failed: FATAL:  database "CT_Overdose_Data" does not exist

# %%
path = "overdose_datasets/drug_deaths_CT.csv"
df = pd.read_csv(path)

# %%
database_url = "postgresql://postgres:postgres@localhost:5432/ct_overdose_deaths"

# %%
engine = create_engine(database_url)

# %%
table_name = "ct_overdose_deaths"
df.to_sql(table_name, engine, index=False, if_exists="replace")
# Out:
# 105

# %%
conn = engine.connect()

# %%
data = pd.read_sql("SELECT * FROM ct_overdose_deaths", conn)

# %%
data
# Out:
#       Unnamed: 0       ID             Date  DateType   Age     Sex  \
# 0              1  13-0102   3/21/2013 0:00       0.0  48.0    Male
# 1              4  13-0052   2/13/2013 0:00       0.0  22.0    Male
# 2              5  14-0277   6/29/2014 0:00       0.0  23.0    Male
# 3              6  12-0205   8/12/2012 0:00       0.0  21.0  Female
# 4              7  13-0404  11/10/2013 0:00       0.0  40.0  Female
# ...          ...      ...              ...       ...   ...     ...
# 4000        5098  14-0166   4/17/2014 0:00       0.0  56.0    Male
# 4001        5099  15-0013    1/7/2015 0:00       1.0  45.0  Female
# 4002        5100  15-0466    9/8/2015 0:00       1.0  43.0    Male
# 4003        5101  17-0618   7/22/2017 0:00       1.0  21.0    Male
# 4004        5102  18-0646   8/14/2018 0:00       0.0  30.0    Male
#
#               Race  ResidenceCity ResidenceCounty ResidenceState  ... Tramad  \
# 0            Black        NORWALK            None           None  ...      0
# 1     Asian, Other       FLUSHING          QUEENS           None  ...      0
# 2            White        BRISTOL            None           None  ...      0
# 3            White  WEST HARTFORD        HARTFORD           None  ...      0
# 4            White         HAMDEN       NEW HAVEN           None  ...      0
# ...            ...            ...             ...            ...  ...    ...
# 4000         White       PLYMOUTH            None           None  ...      0
# 4001         White      WATERBURY       NEW HAVEN             CT  ...      0
# 4002         White       CHESHIRE       NEW HAVEN             CT  ...      0
# 4003         White        MADISON       NEW HAVEN             CT  ...      0
# 4004         White  LAWRENCEVILLE           TIOGA             PA  ...      1
#
#      Morphine_NotHeroin Hydromorphone Other OpiateNOS AnyOpioid MannerofDeath  \
# 0                     0             0  None         0         0      Accident
# 1                     0             0  None         0         0      Accident
# 2                     0             0  None         0         0      Accident
# 3                     0             0  None         0         0      Accident
# 4                     0             0  None         0         0      Accident
# ...                 ...           ...   ...       ...       ...           ...
# 4000                  0             0  None         0         0      Accident
# 4001                  0             0  None         0         1      Accident
# 4002                  0             0  None         0         0      Accident
# 4003                  0             0  None         0         0      Accident
# 4004                  0             0  None         0         1      Accident
#
#                                     DeathCityGeo  \
# 0            Norwalk, CT\n(41.11805, -73.412906)
# 1         Greenwich, CT\n(41.026526, -73.628549)
# 2           BRISTOL, CT\n(41.673037, -72.945791)
# 3     WEST HARTFORD, CT\n(41.762008, -72.741807)
# 4         New Haven, CT\n(41.308252, -72.924161)
# ...                                          ...
# 4000       PLYMOUTH, CT\n(41.671982, -73.052909)
# 4001      WATERBURY, CT\n(41.554261, -73.043069)
# 4002       CHESHIRE, CT\n(41.498834, -72.901448)
# 4003      New Haven, CT\n(41.308252, -72.924161)
# 4004        DANBURY, CT\n(41.393666, -73.451539)
#
#                                 ResidenceCityGeo  \
# 0            NORWALK, CT\n(41.11805, -73.412906)
# 1                                           None
# 2           BRISTOL, CT\n(41.673037, -72.945791)
# 3     WEST HARTFORD, CT\n(41.762008, -72.741807)
# 4            HAMDEN, CT\n(41.382918, -72.907743)
# ...                                          ...
# 4000       PLYMOUTH, CT\n(41.671982, -73.052909)
# 4001      WATERBURY, CT\n(41.554261, -73.043069)
# 4002       CHESHIRE, CT\n(41.498834, -72.901448)
# 4003         MADISON, CT\n(41.271447, -72.60086)
# 4004                                        None
#
#                              InjuryCityGeo
# 0              CT\n(41.575155, -72.738288)
# 1              CT\n(41.575155, -72.738288)
# 2              CT\n(41.575155, -72.738288)
# 3              CT\n(41.575155, -72.738288)
# 4              CT\n(41.575155, -72.738288)
# ...                                    ...
# 4000           CT\n(41.575155, -72.738288)
# 4001           CT\n(41.575155, -72.738288)
# 4002           CT\n(41.575155, -72.738288)
# 4003           CT\n(41.575155, -72.738288)
# 4004  DANBURY, CT\n(41.393666, -73.451539)
#
# [4005 rows x 42 columns]
